# %% [markdown]
# # Face Generation
#
# In this project, you'll define and train a DCGAN on a dataset of faces. Your goal is to get a generator network to generate *new* images of faces that look as realistic as possible!
#
# The project will be broken down into a series of tasks from **loading in data to defining and training adversarial networks**. At the end of the notebook, you'll be able to visualize the results of your trained Generator to see how it performs; your generated samples should look like fairly realistic faces with small amounts of noise.
#
# ### Get the Data
#
# You'll be using the [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) to train your adversarial networks.
#
# This dataset is more complex than the number datasets (like MNIST or SVHN) you've been working with, and so, you should prepare to define deeper networks and train them for a longer time to get good results. It is suggested that you utilize a GPU for training.
#
# ### Pre-processed Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. Some sample data is show below.
#
# <img src='assets/processed_face_data.png' width=60% />
#
# > If you are working locally, you can download this data [by clicking here](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/November/5be7eb6f_processed-celeba-small/processed-celeba-small.zip)
#
# This is a zip file that you'll need to extract in the home directory of this notebook for further loading and processing. After extracting the data, you should be left with a directory of data `processed_celeba_small/`

# %%
# can comment out after executing
# !unzip processed_celeba_small.zip

# %%
data_dir = 'processed_celeba_small/'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import problem_unittests as tests
#import helper

# %matplotlib inline

# %% [markdown]
# ## Visualize the CelebA Data
#
# The [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations. Since you're going to be generating faces, you won't need the annotations, you'll only need the images. Note that these are color images with [3 color channels (RGB)](https://en.wikipedia.org/wiki/Channel_(digital_image)#RGB_Images) each.
#
# ### Pre-process and Load the Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. This *pre-processed* dataset is a smaller subset of the very large CelebA data.
#
# > There are a few other steps that you'll need to **transform** this data and create a **DataLoader**.
#
# #### Exercise: Complete the following `get_dataloader` function, such that it satisfies these requirements:
#
# * Your images should be square, Tensor images of size `image_size x image_size` in the x and y dimension.
# * Your function should return a DataLoader that shuffles and batches these Tensor images.
#
# #### ImageFolder
#
# To create a dataset given a directory of images, it's recommended that you use PyTorch's [ImageFolder](https://pytorch.org/docs/0.4.0/torchvision/datasets.html#imagefolder) wrapper, with a root directory `processed_celeba_small/` and data transformation passed in.

# %%
# necessary imports
import torch
from torchvision import datasets
from torchvision import transforms
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
from torch.autograd import Variable
import numpy as np
import torch.optim as optim

# %% [markdown]
# ### Training on GPU
#
# Check if you can train on GPU. Here, we'll set this as a boolean variable `train_on_gpu`. Later, you'll be responsible for making sure that
# >* Models,
# * Model inputs, and
# * Loss function arguments
#
# Are moved to GPU, where appropriate.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Check for a GPU
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu:
    print('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Training on GPU!')
# Out:
# Training on GPU!

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
def get_dataloader(batch_size, image_size, data_dir='processed_celeba_small/'):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param img_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    """
    # TODO: Implement function and return a dataloader
    data_transformer = transforms.Compose([transforms.Resize(image_size), 
                                           transforms.ToTensor(),])
    #transforms.Normalize((0.5, 0.5, 0.5),(0.5, 0.5, 0.5))
    dataset = datasets.ImageFolder(data_dir,data_transformer)
    data_loader = torch.utils.data.DataLoader(dataset, batch_size = batch_size, shuffle = True)
    
    return data_loader

# %% [markdown]
# ## Create a DataLoader
#
# #### Exercise: Create a DataLoader `celeba_train_loader` with appropriate hyperparameters.
#
# Call the above function and create a dataloader to view images.
# * You can decide on any reasonable `batch_size` parameter
# * Your `image_size` **must be** `32`. Resizing the data to a smaller size will make for faster training, while still creating convincing images of faces!

# %%
# Define function hyperparameters
batch_size = 32
img_size = 32

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Call your function and get a dataloader
celeba_train_loader = get_dataloader(batch_size, img_size)

# %% [markdown]
# Next, you can view some images! You should seen square images of somewhat-centered faces.
#
# Note: You'll need to convert the Tensor images into a NumPy type and transpose the dimensions to correctly display an image, suggested `imshow` code is below, but it may not be perfect.

# %%
# helper display function
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# obtain one batch of training images
dataiter = iter(celeba_train_loader)
images, _ = dataiter.next() # _ for no labels

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(8, 4))
plot_size= 8
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])

# %% [markdown]
# #### Exercise: Pre-process your image data and scale it to a pixel range of -1 to 1
#
# You need to do a bit of pre-processing; you know that the output of a `tanh` activated generator will contain pixel values in a range from -1 to 1, and so, we need to rescale our training images to a range of -1 to 1. (Right now, they are in a range from 0-1.)

# %%
# TODO: Complete the scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    # assume x is scaled to (0, 1)
    # scale to feature_range and return scaled x
    min_range, max_range = feature_range
    x = (max_range - min_range) * x + min_range
    return x

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# check scaled range
# should be close to -1 to 1
img = images[0]
scaled_img = scale(img)

print('Min: ', scaled_img.min())
print('Max: ', scaled_img.max())
# Out:
# Min:  tensor(-0.9765)
# Max:  tensor(1.)

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.
#
# ## Discriminator
#
# Your first task will be to define the discriminator. This is a convolutional classifier like you've built before, only without any maxpooling layers. To deal with this complex data, it's suggested you use a deep network with **normalization**. You are also allowed to create any helper functions that may be useful.
#
# #### Exercise: Complete the Discriminator class
# * The inputs to the discriminator are 32x32x3 tensor images
# * The output should be a single value that will indicate whether a given image is real or fake

# %%
# helper conv functions
def create_conv_layer(inputs, outputs, kernel_size=4, stride=2, padding=1, batch_norm=True):
    nn_layers = []
    layer = nn.Conv2d(inputs, outputs, kernel_size, stride, padding, bias=False)
    nn_layers.append(layer)
    if batch_norm:
        nn_layers.append(nn.BatchNorm2d(outputs))
    return nn.Sequential(*nn_layers)

def create_deconv_layer(inputs, outputs, kernel_size=4, stride=2, padding=1, batch_norm=True):
    nn_layers = []
    layer = nn.ConvTranspose2d(inputs, outputs, kernel_size, stride, padding, bias=False)
    nn_layers.append(layer)
    if batch_norm:
        nn_layers.append(nn.BatchNorm2d(outputs))
    return nn.Sequential(*nn_layers)

# %%
class Discriminator(nn.Module):

    def __init__(self, conv_dim):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        super(Discriminator, self).__init__()
        # complete init function
        #input parameters
        self.conv_dim = conv_dim
        self.leaky_relu_slope = torch.tensor([0.3])
        # Conv layers
        self.conv1 = create_conv_layer(3, conv_dim, 4, batch_norm=False)
        self.conv2 = create_conv_layer(conv_dim, conv_dim*2, 4, batch_norm=True)
        self.conv3 = create_conv_layer(conv_dim*2, conv_dim*4, 4, batch_norm=True)
        # self.conv4 = create_conv_layer(conv_dim*4, conv_dim*4, 4, batch_norm = True)
        # Fully connected layer
        self.fc1 = nn.Linear(conv_dim*4*4*4, 1)

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: Discriminator logits; the output of the neural network
        """
        # define feedforward behavior
        x = F.leaky_relu(self.conv1(x), self.leaky_relu_slope.item())
        # print(x.size())
        x = F.leaky_relu(self.conv2(x), self.leaky_relu_slope.item())
        # print(x.size())
        x = F.leaky_relu(self.conv3(x), self.leaky_relu_slope.item())
        # x = F.leaky_relu(self.conv4(x), self.leaky_relu_slope.item())
        x = x.view(-1, self.conv_dim*4*4*4)
        x = self.fc1(x)
        return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(Discriminator)
# Out:
# Tests Passed

# %% [markdown]
# ## Generator
#
# The generator should upsample an input and generate a *new* image of the same size as our training data `32x32x3`. This should be mostly transpose convolutional layers with normalization applied to the outputs.
#
# #### Exercise: Complete the Generator class
# * The inputs to the generator are vectors of some length `z_size`
# * The output should be a image of shape `32x32x3`

# %%
class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim):
        """
        Initialize the Generator Module
        :param z_size: The length of the input latent vector, z
        :param conv_dim: The depth of the inputs to the *last* transpose convolutional layer
        """
        super(Generator, self).__init__()
        # complete init function
        self.conv_dim = conv_dim
        self.fc1 = nn.Linear(z_size, conv_dim*4*4*4)
        self.deconv1 = create_deconv_layer(conv_dim*4, conv_dim*2, 4)
        self.deconv2 = create_deconv_layer(conv_dim*2, conv_dim, 4)
        self.deconv3 = create_deconv_layer(conv_dim, 3, 4, batch_norm=False)

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: A 32x32x3 Tensor image as output
        """
        # define feedforward behavior
        x = self.fc1(x)

        x = x.view(-1, self.conv_dim*4, 4, 4)
        x = F.relu(self.deconv1(x))
        x = F.relu(self.deconv2(x))
        x = self.deconv3(x)
        x = F.tanh(x)
        # print(x.size())
        return x

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(Generator)
# Out:
# Tests Passed

# %% [markdown]
# ## Initialize the weights of your networks
#
# To help your models converge, you should initialize the weights of the convolutional and linear layers in your model. From reading the [original DCGAN paper](https://arxiv.org/pdf/1511.06434.pdf), they say:
# > All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.
#
# So, your next task will be to define a weight initialization function that does just this!
#
# You can refer back to the lesson on weight initialization or even consult existing model code, such as that from [the `networks.py` file in CycleGAN Github repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py) to help you complete this function.
#
# #### Exercise: Complete the weight initialization function
#
# * This should initialize only **convolutional** and **linear** layers
# * Initialize the weights to a normal distribution, centered around 0, with a standard deviation of 0.02.
# * The bias terms, if they exist, may be left alone or set to 0.

# %%
def weights_init_normal(m):
    """
    Applies initial weights to certain layers in a model .
    The weights are taken from a normal distribution 
    with mean = 0, std dev = 0.02.
    :param m: A module or layer in a network    
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__
    
    # TODO: Apply initial weights to convolutional and linear layers
    print(classname)
    if 'Conv' in classname:
        print('Found conv layer!')
        torch.nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif 'Linear' in classname:
        print('Found linear layer!')
        torch.nn.init.normal_(m.weight.data, 0.0, 0.02)

# %% [markdown]
# ## Build complete network
#
# Define your models' hyperparameters and instantiate the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
def build_network(d_conv_dim, g_conv_dim, z_size):
    # define discriminator and generator
    D = Discriminator(d_conv_dim)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim)

    # initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)

    print(D)
    print(G)
    
    return D, G

# %% [markdown]
# #### Exercise: Define model hyperparameters

# %%
# Define model hyperparams
d_conv_dim = 32
g_conv_dim = 32
z_size = 128

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
D, G = build_network(d_conv_dim, g_conv_dim, z_size)
D = D.to(device)
G = G.to(device)
# Out:
# Conv2d
# Found conv layer!
# Sequential
# Conv2d
# Found conv layer!
# BatchNorm2d
# Sequential
# Conv2d
# Found conv layer!
# BatchNorm2d
# Sequential
# Linear
# Found linear layer!
# Discriminator
# Linear
# Found linear layer!
# ConvTranspose2d
# Found conv layer!
# BatchNorm2d
# Sequential
# ConvTranspose2d
# Found conv layer!
# BatchNorm2d
# Sequential
# ConvTranspose2d
# Found conv layer!
# Sequential
# Generator
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc1): Linear(in_features=2048, out_features=1, bias=True)
# )
# Generator(
#   (fc1): Linear(in_features=128, out_features=2048, bias=True)
#   (deconv1): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv2): Sequential(
#     (0): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv3): Sequential(
#     (0): ConvTranspose2d(32, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
# )

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses for both types of adversarial networks.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get the discriminator to *think* its generated images are *real*.
#
# #### Exercise: Complete real and fake loss functions
#
# **You may choose to use either cross entropy or a least squares error loss to complete the following `real_loss` and `fake_loss` functions.**

# %%
def real_loss(D_out, smooth = False):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''
    batch_size = D_out.size(0)
    if smooth:
        labels = torch.ones(batch_size)*0.9
    else:
        labels = torch.ones(batch_size)
    labels = labels.to(device)
    criterion = nn.BCEWithLogitsLoss()
    loss = criterion(D_out.squeeze(), labels)
    return loss

def fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''
    batch_size = D_out.size(0)
    labels = torch.zeros(batch_size)
    labels = labels.to(device)
    criterion = nn.BCEWithLogitsLoss()
    loss = criterion(D_out.squeeze(), labels)
    return loss

# %% [markdown]
# ## Optimizers
#
# #### Exercise: Define optimizers for your Discriminator (D) and Generator (G)
#
# Define optimizers for your models with appropriate hyperparameters.

# %%
# Create optimizers for the discriminator D and generator G
lr = 0.003
beta1 = 0.3
beta2 = 0.999 # as default

d_optimizer = optim.Adam(D.parameters(), lr, betas= (beta1, beta2))
g_optimizer = optim.Adam(G.parameters(), lr, betas = (beta1, beta2))

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. You'll use your functions `real_loss` and `fake_loss` to help you calculate the discriminator losses.
#
# * You should train the discriminator by alternating on real and fake images
# * Then the generator, which tries to trick the discriminator and should have an opposing loss function
#
#
# #### Saving Samples
#
# You've been given some code to print out some loss statistics and save some generated "fake" samples.

# %% [markdown]
# #### Exercise: Complete the training function
#
# Keep in mind that, if you've moved your models to GPU, you'll also have to move any model inputs to GPU.

# %%
def train(D, G, n_epochs, print_every=50):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''


    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()

    # epoch training loop
    for epoch in range(n_epochs):

        # batch training loop
        for batch_i, (real_images, _) in enumerate(celeba_train_loader):

            batch_size = real_images.size(0)
            real_images = scale(real_images)

            # ===============================================
            #         YOUR CODE HERE: TRAIN THE NETWORKS
            # ===============================================
            # 1. Train the discriminator on real and fake images
            d_optimizer.zero_grad()
            
            real_images = real_images.to(device)
            
            d_realOut = D(real_images)
            d_realLoss = real_loss(d_realOut)
            
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            z = z.to(device)
            
            fake_images = G(z)
            fake_images = fake_images.to(device)
            d_fakeOut = D(fake_images)
            d_fakeLoss = fake_loss(d_fakeOut)

            d_loss = d_realLoss + d_fakeLoss
            
            d_loss.backward()
            d_optimizer.step()
            
            
            # 2. Train the generator with an adversarial loss
            g_optimizer.zero_grad()
            
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            z = z.to(device)
            
            fake_images = G(z)
            g_out = D(fake_images)
            g_loss = real_loss(g_out)
            g_loss.backward()
            g_optimizer.step()
            
            
            # ===============================================
            #              END OF YOUR CODE
            # ===============================================

            # Print some loss stats
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item()))


        ## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        samples_z = G(fixed_z)
        samples.append(samples_z)
        G.train() # back to training mode

    # Save training generator samples
    with open('train_samples.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    # finally return losses
    return losses

# %% [markdown]
# Set your number of training epochs and train your GAN!

# %%
torch.cuda.is_available()
# Out:
# True

# %%
# set number of epochs 
n_epochs = 20

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# call training function
losses = train(D, G, n_epochs=n_epochs)
# Out:
# Epoch [    1/   20] | d_loss: 1.5611 | g_loss: 3.8755
# Epoch [    1/   20] | d_loss: 1.3893 | g_loss: 1.1535
# Epoch [    1/   20] | d_loss: 1.3407 | g_loss: 0.8899
# Epoch [    1/   20] | d_loss: 1.4419 | g_loss: 1.0047
# Epoch [    1/   20] | d_loss: 1.4537 | g_loss: 0.8006
# Epoch [    1/   20] | d_loss: 1.4802 | g_loss: 1.1036
# Epoch [    1/   20] | d_loss: 1.2614 | g_loss: 0.9113
# Epoch [    1/   20] | d_loss: 1.2717 | g_loss: 1.1883
# Epoch [    1/   20] | d_loss: 1.4113 | g_loss: 0.6695
# Epoch [    1/   20] | d_loss: 1.3563 | g_loss: 0.7394
# Epoch [    1/   20] | d_loss: 1.3568 | g_loss: 1.2779
# Epoch [    1/   20] | d_loss: 1.2628 | g_loss: 1.2888
# Epoch [    1/   20] | d_loss: 1.3353 | g_loss: 1.3394
# Epoch [    1/   20] | d_loss: 1.3951 | g_loss: 0.7096
# Epoch [    1/   20] | d_loss: 1.3750 | g_loss: 1.0461
# Epoch [    1/   20] | d_loss: 1.2450 | g_loss: 0.8253
# Epoch [    1/   20] | d_loss: 1.3643 | g_loss: 1.0979
# Epoch [    1/   20] | d_loss: 1.3219 | g_loss: 1.1964
# Epoch [    1/   20] | d_loss: 1.3161 | g_loss: 0.8697
# Epoch [    1/   20] | d_loss: 1.3278 | g_loss: 0.9364
# Epoch [    1/   20] | d_loss: 1.2979 | g_loss: 1.1833
# Epoch [    1/   20] | d_loss: 1.2918 | g_loss: 0.8471
# Epoch [    1/   20] | d_loss: 1.4695 | g_loss: 0.7048
# Epoch [    1/   20] | d_loss: 1.2539 | g_loss: 0.9081
# Epoch [    1/   20] | d_loss: 1.3510 | g_loss: 0.6945
# Epoch [    1/   20] | d_loss: 1.2588 | g_loss: 1.0509
# Epoch [    1/   20] | d_loss: 1.3940 | g_loss: 0.8258
# Epoch [    1/   20] | d_loss: 1.1647 | g_loss: 0.8466
# Epoch [    1/   20] | d_loss: 1.3337 | g_loss: 0.7974
# Epoch [    1/   20] | d_loss: 1.3243 | g_loss: 0.8396
# Epoch [    2/   20] | d_loss: 1.3437 | g_loss: 1.0070
# Epoch [    2/   20] | d_loss: 1.1747 | g_loss: 0.9035
# Epoch [    2/   20] | d_loss: 1.2382 | g_loss: 0.9215
# Epoch [    2/   20] | d_loss: 1.2115 | g_loss: 0.8542
# Epoch [    2/   20] | d_loss: 1.2954 | g_loss: 0.9211
# Epoch [    2/   20] | d_loss: 1.3961 | g_loss: 0.9157
# Epoch [    2/   20] | d_loss: 1.2432 | g_loss: 1.0815
# Epoch [    2/   20] | d_loss: 1.2811 | g_loss: 0.7914
# Epoch [    2/   20] | d_loss: 1.3174 | g_loss: 0.9736
# Epoch [    2/   20] | d_loss: 1.4596 | g_loss: 0.8451
# Epoch [    2/   20] | d_loss: 1.3827 | g_loss: 0.9048
# Epoch [    2/   20] | d_loss: 1.3248 | g_loss: 0.9947
# Epoch [    2/   20] | d_loss: 1.3749 | g_loss: 0.9658
# Epoch [    2/   20] | d_loss: 1.6003 | g_loss: 1.1849
# Epoch [    2/   20] | d_loss: 1.3954 | g_loss: 0.5387
# Epoch [    2/   20] | d_loss: 1.2055 | g_loss: 0.8701
# Epoch [    2/   20] | d_loss: 1.3405 | g_loss: 0.8432
# Epoch [    2/   20] | d_loss: 1.4597 | g_loss: 1.2977
# Epoch [    2/   20] | d_loss: 1.3574 | g_loss: 0.7742
# Epoch [    2/   20] | d_loss: 1.2984 | g_loss: 0.9031
# Epoch [    2/   20] | d_loss: 1.4640 | g_loss: 0.7080
# Epoch [    2/   20] | d_loss: 1.5262 | g_loss: 0.9906
# Epoch [    2/   20] | d_loss: 1.2818 | g_loss: 0.7839
# Epoch [    2/   20] | d_loss: 1.3905 | g_loss: 1.1154
# Epoch [    2/   20] | d_loss: 1.3720 | g_loss: 0.7153
# Epoch [    2/   20] | d_loss: 1.3343 | g_loss: 0.7484
# Epoch [    2/   20] | d_loss: 1.4304 | g_loss: 1.2194
# Epoch [    2/   20] | d_loss: 1.3648 | g_loss: 1.0509
# Epoch [    2/   20] | d_loss: 1.3785 | g_loss: 0.9305
# Epoch [    2/   20] | d_loss: 1.2396 | g_loss: 1.4446
# Epoch [    2/   20] | d_loss: 1.3931 | g_loss: 0.7660
# Epoch [    2/   20] | d_loss: 1.3365 | g_loss: 0.7491
# Epoch [    2/   20] | d_loss: 1.2503 | g_loss: 0.6368
# Epoch [    2/   20] | d_loss: 1.3031 | g_loss: 0.7374
# Epoch [    2/   20] | d_loss: 1.2759 | g_loss: 0.7866
# Epoch [    2/   20] | d_loss: 1.3017 | g_loss: 1.1187
# Epoch [    2/   20] | d_loss: 1.1951 | g_loss: 0.9253
# Epoch [    2/   20] | d_loss: 1.3519 | g_loss: 0.7705
# Epoch [    2/   20] | d_loss: 1.2915 | g_loss: 1.2703
# Epoch [    2/   20] | d_loss: 1.3145 | g_loss: 1.0520
# Epoch [    2/   20] | d_loss: 1.4643 | g_loss: 0.8295
# Epoch [    3/   20] | d_loss: 1.4467 | g_loss: 0.9396
# Epoch [    3/   20] | d_loss: 1.3533 | g_loss: 0.6259
# Epoch [    3/   20] | d_loss: 1.3725 | g_loss: 0.8412
# Epoch [    3/   20] | d_loss: 1.2856 | g_loss: 0.8558
# Epoch [    3/   20] | d_loss: 1.1961 | g_loss: 1.0144
# Epoch [    3/   20] | d_loss: 1.2781 | g_loss: 1.0570
# Epoch [    3/   20] | d_loss: 1.3451 | g_loss: 1.1769
# Epoch [    3/   20] | d_loss: 1.3133 | g_loss: 0.9946
# Epoch [    3/   20] | d_loss: 1.2509 | g_loss: 0.9874
# Epoch [    3/   20] | d_loss: 1.2694 | g_loss: 1.0766
# Epoch [    3/   20] | d_loss: 1.2566 | g_loss: 1.0411
# Epoch [    3/   20] | d_loss: 1.2417 | g_loss: 1.0581
# Epoch [    3/   20] | d_loss: 1.1872 | g_loss: 0.9402
# Epoch [    3/   20] | d_loss: 1.3161 | g_loss: 0.7360
# Epoch [    3/   20] | d_loss: 1.3594 | g_loss: 0.9884
# Epoch [    3/   20] | d_loss: 1.2837 | g_loss: 1.1450
# Epoch [    3/   20] | d_loss: 1.1745 | g_loss: 1.0426
# Epoch [    3/   20] | d_loss: 1.3087 | g_loss: 0.7294
# Epoch [    3/   20] | d_loss: 1.2455 | g_loss: 1.2081
# Epoch [    3/   20] | d_loss: 1.3247 | g_loss: 1.0254
# Epoch [    3/   20] | d_loss: 1.4378 | g_loss: 0.7834
# Epoch [    3/   20] | d_loss: 1.3469 | g_loss: 1.1355
# Epoch [    3/   20] | d_loss: 1.2636 | g_loss: 1.1694
# Epoch [    3/   20] | d_loss: 1.1497 | g_loss: 1.0877
# Epoch [    3/   20] | d_loss: 1.4776 | g_loss: 1.4048
# Epoch [    3/   20] | d_loss: 1.5813 | g_loss: 1.3099
# Epoch [    3/   20] | d_loss: 1.3168 | g_loss: 0.8642
# Epoch [    3/   20] | d_loss: 1.3542 | g_loss: 0.6525
# Epoch [    3/   20] | d_loss: 1.2863 | g_loss: 0.8464
# Epoch [    3/   20] | d_loss: 1.3559 | g_loss: 1.3325
# Epoch [    3/   20] | d_loss: 1.2382 | g_loss: 1.1240
# Epoch [    3/   20] | d_loss: 1.3928 | g_loss: 0.7663
# Epoch [    3/   20] | d_loss: 1.3322 | g_loss: 0.7837
# Epoch [    3/   20] | d_loss: 1.2936 | g_loss: 1.0747
# Epoch [    3/   20] | d_loss: 1.2640 | g_loss: 0.9554
# Epoch [    3/   20] | d_loss: 1.1466 | g_loss: 0.9765
# Epoch [    3/   20] | d_loss: 1.1372 | g_loss: 0.9177
# Epoch [    3/   20] | d_loss: 1.2885 | g_loss: 0.9430
# Epoch [    3/   20] | d_loss: 1.3077 | g_loss: 0.8927
# Epoch [    3/   20] | d_loss: 1.3456 | g_loss: 1.1039
# Epoch [    3/   20] | d_loss: 1.3002 | g_loss: 1.0417
# Epoch [    3/   20] | d_loss: 1.3043 | g_loss: 1.1466
# Epoch [    3/   20] | d_loss: 1.2944 | g_loss: 1.0166
# Epoch [    3/   20] | d_loss: 1.3876 | g_loss: 0.9619
# Epoch [    3/   20] | d_loss: 1.4604 | g_loss: 0.6472
# Epoch [    3/   20] | d_loss: 1.3244 | g_loss: 1.3163
# Epoch [    3/   20] | d_loss: 1.3651 | g_loss: 0.7681
# Epoch [    3/   20] | d_loss: 1.4384 | g_loss: 1.3624
# Epoch [    3/   20] | d_loss: 1.2297 | g_loss: 1.1403
# Epoch [    3/   20] | d_loss: 1.1826 | g_loss: 0.8899
# Epoch [    3/   20] | d_loss: 1.3351 | g_loss: 0.8530
# Epoch [    3/   20] | d_loss: 1.2445 | g_loss: 1.1148
# Epoch [    3/   20] | d_loss: 1.2584 | g_loss: 0.7764
# Epoch [    3/   20] | d_loss: 1.3228 | g_loss: 1.1762
# Epoch [    3/   20] | d_loss: 1.2075 | g_loss: 1.1014
# Epoch [    3/   20] | d_loss: 1.3259 | g_loss: 0.9464
# Epoch [    3/   20] | d_loss: 1.1927 | g_loss: 1.1315
# Epoch [    4/   20] | d_loss: 1.2189 | g_loss: 0.8734
# Epoch [    4/   20] | d_loss: 1.2442 | g_loss: 0.7755
# Epoch [    4/   20] | d_loss: 1.2161 | g_loss: 1.0091
# Epoch [    4/   20] | d_loss: 1.2261 | g_loss: 1.2083
# Epoch [    4/   20] | d_loss: 1.2891 | g_loss: 1.0793
# Epoch [    4/   20] | d_loss: 1.2664 | g_loss: 0.6727
# Epoch [    4/   20] | d_loss: 1.2326 | g_loss: 1.0351
# Epoch [    4/   20] | d_loss: 1.2539 | g_loss: 1.2875
# Epoch [    4/   20] | d_loss: 1.1363 | g_loss: 0.8562
# Epoch [    4/   20] | d_loss: 1.1961 | g_loss: 1.1406
# Epoch [    4/   20] | d_loss: 1.1559 | g_loss: 0.6699
# Epoch [    4/   20] | d_loss: 1.1383 | g_loss: 1.1942
# Epoch [    4/   20] | d_loss: 1.5060 | g_loss: 0.6722
# Epoch [    4/   20] | d_loss: 1.1649 | g_loss: 1.3079
# Epoch [    4/   20] | d_loss: 1.1698 | g_loss: 0.8719
# Epoch [    4/   20] | d_loss: 1.3952 | g_loss: 1.3438
# Epoch [    4/   20] | d_loss: 1.2453 | g_loss: 0.9837
# Epoch [    4/   20] | d_loss: 1.1959 | g_loss: 1.5688
# Epoch [    4/   20] | d_loss: 1.2287 | g_loss: 1.1552
# Epoch [    4/   20] | d_loss: 1.1582 | g_loss: 1.3044
# Epoch [    4/   20] | d_loss: 1.0808 | g_loss: 1.1424
# Epoch [    4/   20] | d_loss: 1.2366 | g_loss: 1.0341
# Epoch [    4/   20] | d_loss: 1.2962 | g_loss: 1.1629
# Epoch [    4/   20] | d_loss: 1.3159 | g_loss: 0.9822
# Epoch [    4/   20] | d_loss: 1.0690 | g_loss: 1.2684
# Epoch [    4/   20] | d_loss: 1.1750 | g_loss: 1.0894
# Epoch [    4/   20] | d_loss: 1.2070 | g_loss: 0.8945
# Epoch [    4/   20] | d_loss: 1.3780 | g_loss: 1.6497
# Epoch [    4/   20] | d_loss: 1.1943 | g_loss: 0.9109
# Epoch [    4/   20] | d_loss: 1.2043 | g_loss: 1.5994
# Epoch [    4/   20] | d_loss: 1.1423 | g_loss: 0.9286
# Epoch [    4/   20] | d_loss: 1.1983 | g_loss: 0.9918
# Epoch [    4/   20] | d_loss: 1.1870 | g_loss: 1.8742
# Epoch [    4/   20] | d_loss: 1.3307 | g_loss: 1.3765
# Epoch [    4/   20] | d_loss: 1.1959 | g_loss: 1.3754
# Epoch [    4/   20] | d_loss: 1.4196 | g_loss: 1.6247
# Epoch [    4/   20] | d_loss: 1.2368 | g_loss: 0.9701
# Epoch [    4/   20] | d_loss: 1.2254 | g_loss: 1.4289
# Epoch [    4/   20] | d_loss: 1.4134 | g_loss: 1.9728
# Epoch [    4/   20] | d_loss: 1.3032 | g_loss: 1.1155
# Epoch [    4/   20] | d_loss: 1.4255 | g_loss: 0.9464
# Epoch [    4/   20] | d_loss: 1.2561 | g_loss: 0.7530
# Epoch [    4/   20] | d_loss: 1.3863 | g_loss: 1.6128
# Epoch [    4/   20] | d_loss: 1.2268 | g_loss: 1.5031
# Epoch [    4/   20] | d_loss: 1.3171 | g_loss: 1.9286
# Epoch [    4/   20] | d_loss: 1.4388 | g_loss: 0.8484
# Epoch [    4/   20] | d_loss: 1.4590 | g_loss: 0.4030
# Epoch [    4/   20] | d_loss: 1.2350 | g_loss: 1.2419
# Epoch [    4/   20] | d_loss: 1.1023 | g_loss: 1.3354
# Epoch [    4/   20] | d_loss: 0.8578 | g_loss: 1.4476
# Epoch [    4/   20] | d_loss: 1.3504 | g_loss: 0.6753
# Epoch [    4/   20] | d_loss: 1.1962 | g_loss: 1.1482
# Epoch [    4/   20] | d_loss: 1.3399 | g_loss: 1.9669
# Epoch [    4/   20] | d_loss: 1.3520 | g_loss: 0.6217
# Epoch [    4/   20] | d_loss: 1.0339 | g_loss: 1.0539
# Epoch [    4/   20] | d_loss: 1.2848 | g_loss: 0.7874
# Epoch [    4/   20] | d_loss: 1.0870 | g_loss: 1.1623
# Epoch [    5/   20] | d_loss: 1.2943 | g_loss: 0.9966
# Epoch [    5/   20] | d_loss: 1.1803 | g_loss: 0.8933
# Epoch [    5/   20] | d_loss: 1.2281 | g_loss: 0.5438
# Epoch [    5/   20] | d_loss: 1.2557 | g_loss: 0.7907
# Epoch [    5/   20] | d_loss: 1.0720 | g_loss: 0.8312
# Epoch [    5/   20] | d_loss: 1.0538 | g_loss: 1.0288
# Epoch [    5/   20] | d_loss: 1.3816 | g_loss: 0.5957
# Epoch [    5/   20] | d_loss: 1.1161 | g_loss: 0.8326
# Epoch [    5/   20] | d_loss: 1.3373 | g_loss: 2.1460
# Epoch [    5/   20] | d_loss: 1.7369 | g_loss: 2.3694
# Epoch [    5/   20] | d_loss: 0.9926 | g_loss: 1.1720
# Epoch [    5/   20] | d_loss: 1.1208 | g_loss: 1.0719
# Epoch [    5/   20] | d_loss: 1.1939 | g_loss: 1.1041
# Epoch [    5/   20] | d_loss: 1.1961 | g_loss: 1.4711
# Epoch [    5/   20] | d_loss: 1.3590 | g_loss: 1.2889
# Epoch [    5/   20] | d_loss: 1.1424 | g_loss: 0.8406
# Epoch [    5/   20] | d_loss: 0.9226 | g_loss: 1.6851
# Epoch [    5/   20] | d_loss: 1.1529 | g_loss: 1.3291
# Epoch [    5/   20] | d_loss: 1.2141 | g_loss: 1.0150
# Epoch [    5/   20] | d_loss: 0.9928 | g_loss: 1.2150
# Epoch [    5/   20] | d_loss: 1.0193 | g_loss: 2.1068
# Epoch [    5/   20] | d_loss: 1.1456 | g_loss: 2.0307
# Epoch [    5/   20] | d_loss: 1.0462 | g_loss: 0.9772
# Epoch [    5/   20] | d_loss: 1.3555 | g_loss: 0.8670
# Epoch [    5/   20] | d_loss: 1.1457 | g_loss: 0.9543
# Epoch [    5/   20] | d_loss: 1.2975 | g_loss: 2.2347
# Epoch [    5/   20] | d_loss: 1.1390 | g_loss: 1.1270
# Epoch [    5/   20] | d_loss: 1.1201 | g_loss: 1.8239
# Epoch [    5/   20] | d_loss: 1.1074 | g_loss: 1.0064
# Epoch [    5/   20] | d_loss: 1.3465 | g_loss: 1.9235
# Epoch [    5/   20] | d_loss: 0.9754 | g_loss: 1.3144
# Epoch [    5/   20] | d_loss: 1.2468 | g_loss: 1.8164
# Epoch [    5/   20] | d_loss: 0.8345 | g_loss: 0.6329
# Epoch [    5/   20] | d_loss: 1.0322 | g_loss: 1.6521
# Epoch [    5/   20] | d_loss: 0.9724 | g_loss: 1.9721
# Epoch [    5/   20] | d_loss: 0.9857 | g_loss: 0.8703
# Epoch [    5/   20] | d_loss: 1.0289 | g_loss: 1.2317
# Epoch [    5/   20] | d_loss: 1.3137 | g_loss: 1.0294
# Epoch [    5/   20] | d_loss: 1.2353 | g_loss: 0.9622
# Epoch [    5/   20] | d_loss: 1.5900 | g_loss: 1.8555
# Epoch [    5/   20] | d_loss: 1.0639 | g_loss: 0.7133
# Epoch [    5/   20] | d_loss: 0.9444 | g_loss: 1.9090
# Epoch [    5/   20] | d_loss: 1.3940 | g_loss: 1.9787
# Epoch [    5/   20] | d_loss: 0.8273 | g_loss: 1.0254
# Epoch [    5/   20] | d_loss: 1.2288 | g_loss: 2.2005
# Epoch [    5/   20] | d_loss: 1.1321 | g_loss: 1.2648
# Epoch [    5/   20] | d_loss: 1.1562 | g_loss: 1.9423
# Epoch [    5/   20] | d_loss: 1.1093 | g_loss: 1.7355
# Epoch [    5/   20] | d_loss: 1.3878 | g_loss: 2.2265
# Epoch [    5/   20] | d_loss: 1.0285 | g_loss: 1.5074
# Epoch [    5/   20] | d_loss: 1.1742 | g_loss: 1.2810
# Epoch [    5/   20] | d_loss: 1.2607 | g_loss: 1.5946
# Epoch [    5/   20] | d_loss: 1.0695 | g_loss: 0.9510
# Epoch [    5/   20] | d_loss: 0.9960 | g_loss: 2.1068
# Epoch [    5/   20] | d_loss: 1.0414 | g_loss: 1.1272
# Epoch [    5/   20] | d_loss: 1.5478 | g_loss: 0.7491
# Epoch [    5/   20] | d_loss: 0.7059 | g_loss: 1.8345
# Epoch [    6/   20] | d_loss: 0.6979 | g_loss: 1.4444
# Epoch [    6/   20] | d_loss: 1.3131 | g_loss: 2.4226
# Epoch [    6/   20] | d_loss: 2.0228 | g_loss: 0.3719
# Epoch [    6/   20] | d_loss: 0.7329 | g_loss: 2.3075
# Epoch [    6/   20] | d_loss: 1.6114 | g_loss: 0.7802
# Epoch [    6/   20] | d_loss: 1.1767 | g_loss: 1.1721
# Epoch [    6/   20] | d_loss: 0.6699 | g_loss: 1.2902
# Epoch [    6/   20] | d_loss: 1.2778 | g_loss: 1.0139
# Epoch [    6/   20] | d_loss: 0.9759 | g_loss: 2.6183
# Epoch [    6/   20] | d_loss: 0.8208 | g_loss: 0.8938
# Epoch [    6/   20] | d_loss: 0.8059 | g_loss: 1.2046
# Epoch [    6/   20] | d_loss: 0.9388 | g_loss: 1.0357
# Epoch [    6/   20] | d_loss: 1.1872 | g_loss: 0.4304
# Epoch [    6/   20] | d_loss: 0.8461 | g_loss: 1.2391
# Epoch [    7/   20] | d_loss: 1.1314 | g_loss: 1.8498
# Epoch [    7/   20] | d_loss: 0.6524 | g_loss: 1.4431
# Epoch [    7/   20] | d_loss: 0.9195 | g_loss: 1.0253
# Epoch [    7/   20] | d_loss: 0.7343 | g_loss: 1.8619
# Epoch [    7/   20] | d_loss: 1.1406 | g_loss: 1.1063
# Epoch [    7/   20] | d_loss: 0.8279 | g_loss: 2.0331
# Epoch [    7/   20] | d_loss: 1.3815 | g_loss: 0.6725
# Epoch [    7/   20] | d_loss: 1.3560 | g_loss: 2.5758
# Epoch [    7/   20] | d_loss: 0.9410 | g_loss: 1.4210
# Epoch [    7/   20] | d_loss: 1.7375 | g_loss: 0.8540
# Epoch [    7/   20] | d_loss: 0.9602 | g_loss: 1.4528
# Epoch [    7/   20] | d_loss: 0.9323 | g_loss: 1.6330
# Epoch [    7/   20] | d_loss: 0.6905 | g_loss: 1.1941
# Epoch [    7/   20] | d_loss: 1.0659 | g_loss: 2.4107
# Epoch [    7/   20] | d_loss: 1.0002 | g_loss: 0.7795
# Epoch [    7/   20] | d_loss: 0.7319 | g_loss: 0.9601
# Epoch [    7/   20] | d_loss: 1.0225 | g_loss: 1.0434
# Epoch [    7/   20] | d_loss: 0.5373 | g_loss: 1.8188
# Epoch [    7/   20] | d_loss: 0.5554 | g_loss: 1.4536
# Epoch [    7/   20] | d_loss: 0.3973 | g_loss: 2.3843
# Epoch [    7/   20] | d_loss: 0.8511 | g_loss: 0.9228
# Epoch [    7/   20] | d_loss: 0.7701 | g_loss: 1.1643
# Epoch [    7/   20] | d_loss: 0.9440 | g_loss: 2.7570
# Epoch [    7/   20] | d_loss: 0.8471 | g_loss: 1.5990
# Epoch [    7/   20] | d_loss: 0.8682 | g_loss: 2.1450
# Epoch [    7/   20] | d_loss: 1.0516 | g_loss: 0.7174
# Epoch [    7/   20] | d_loss: 1.0001 | g_loss: 3.3209
# Epoch [    7/   20] | d_loss: 0.7675 | g_loss: 1.4401
# Epoch [    7/   20] | d_loss: 0.9583 | g_loss: 1.1751
# Epoch [    7/   20] | d_loss: 0.9143 | g_loss: 2.5369
# Epoch [    7/   20] | d_loss: 0.9008 | g_loss: 0.6564
# Epoch [    7/   20] | d_loss: 0.8415 | g_loss: 1.6405
# Epoch [    7/   20] | d_loss: 0.6087 | g_loss: 2.7731
# Epoch [    7/   20] | d_loss: 1.4151 | g_loss: 0.8458
# Epoch [    7/   20] | d_loss: 0.9604 | g_loss: 0.6369
# Epoch [    7/   20] | d_loss: 1.0202 | g_loss: 0.9468
# Epoch [    7/   20] | d_loss: 0.9637 | g_loss: 1.2614
# Epoch [    7/   20] | d_loss: 1.3777 | g_loss: 1.0755
# Epoch [    7/   20] | d_loss: 1.7927 | g_loss: 3.3861
# Epoch [    7/   20] | d_loss: 0.8077 | g_loss: 1.9220
# Epoch [    7/   20] | d_loss: 0.8749 | g_loss: 2.1665
# Epoch [    7/   20] | d_loss: 0.6508 | g_loss: 1.4522
# Epoch [    7/   20] | d_loss: 1.0627 | g_loss: 4.1148
# Epoch [    7/   20] | d_loss: 0.4860 | g_loss: 1.9182
# Epoch [    7/   20] | d_loss: 0.7463 | g_loss: 1.8095
# Epoch [    7/   20] | d_loss: 0.8402 | g_loss: 2.3923
# Epoch [    7/   20] | d_loss: 0.9853 | g_loss: 2.0769
# Epoch [    7/   20] | d_loss: 0.9686 | g_loss: 2.3768
# Epoch [    7/   20] | d_loss: 0.6896 | g_loss: 2.9331
# Epoch [    7/   20] | d_loss: 0.8032 | g_loss: 1.8997
# Epoch [    7/   20] | d_loss: 0.8714 | g_loss: 2.2825
# Epoch [    7/   20] | d_loss: 0.8989 | g_loss: 2.2405
# Epoch [    7/   20] | d_loss: 0.9672 | g_loss: 0.9400
# Epoch [    7/   20] | d_loss: 1.2959 | g_loss: 1.0371
# Epoch [    7/   20] | d_loss: 1.1282 | g_loss: 0.6873
# Epoch [    7/   20] | d_loss: 0.8422 | g_loss: 0.9010
# Epoch [    7/   20] | d_loss: 0.7767 | g_loss: 1.2707
# Epoch [    8/   20] | d_loss: 0.6325 | g_loss: 3.1279
# Epoch [    8/   20] | d_loss: 1.9770 | g_loss: 0.2370
# Epoch [    8/   20] | d_loss: 1.5420 | g_loss: 4.9761
# Epoch [    8/   20] | d_loss: 1.0666 | g_loss: 3.1244
# Epoch [    8/   20] | d_loss: 0.7006 | g_loss: 1.9266
# Epoch [    8/   20] | d_loss: 0.9841 | g_loss: 3.4290
# Epoch [    8/   20] | d_loss: 0.4848 | g_loss: 2.6326
# Epoch [    8/   20] | d_loss: 1.6650 | g_loss: 2.6616
# Epoch [    8/   20] | d_loss: 0.7297 | g_loss: 1.9443
# Epoch [    8/   20] | d_loss: 0.4545 | g_loss: 2.6653
# Epoch [    8/   20] | d_loss: 0.7343 | g_loss: 1.9926
# Epoch [    8/   20] | d_loss: 1.3189 | g_loss: 0.9533
# Epoch [    8/   20] | d_loss: 0.9823 | g_loss: 3.7604
# Epoch [    8/   20] | d_loss: 0.5549 | g_loss: 2.3068
# Epoch [    8/   20] | d_loss: 0.7033 | g_loss: 1.2277
# Epoch [    8/   20] | d_loss: 0.6808 | g_loss: 1.4290
# Epoch [    8/   20] | d_loss: 1.0466 | g_loss: 2.7376
# Epoch [    8/   20] | d_loss: 0.9365 | g_loss: 1.9737
# Epoch [    8/   20] | d_loss: 0.9404 | g_loss: 3.1836
# Epoch [    8/   20] | d_loss: 1.0321 | g_loss: 2.1343
# Epoch [    8/   20] | d_loss: 1.5460 | g_loss: 0.6824
# Epoch [    8/   20] | d_loss: 0.7414 | g_loss: 1.3187
# Epoch [    8/   20] | d_loss: 0.7176 | g_loss: 2.3199
# Epoch [    8/   20] | d_loss: 3.0289 | g_loss: 2.7557
# Epoch [    8/   20] | d_loss: 0.8786 | g_loss: 2.1965
# Epoch [    8/   20] | d_loss: 0.4687 | g_loss: 1.8264
# Epoch [    8/   20] | d_loss: 0.3936 | g_loss: 2.7584
# Epoch [    8/   20] | d_loss: 0.7419 | g_loss: 1.9882
# Epoch [    8/   20] | d_loss: 0.8191 | g_loss: 1.9721
# Epoch [    8/   20] | d_loss: 0.6490 | g_loss: 1.9349
# Epoch [    8/   20] | d_loss: 0.8073 | g_loss: 2.8417
# Epoch [    8/   20] | d_loss: 0.9834 | g_loss: 1.0254
# Epoch [    8/   20] | d_loss: 0.9358 | g_loss: 3.6900
# Epoch [    8/   20] | d_loss: 0.5519 | g_loss: 1.6047
# Epoch [    8/   20] | d_loss: 0.7676 | g_loss: 2.0640
# Epoch [    8/   20] | d_loss: 0.6787 | g_loss: 1.3611
# Epoch [    8/   20] | d_loss: 0.9363 | g_loss: 1.8496
# Epoch [    8/   20] | d_loss: 0.6547 | g_loss: 2.0426
# Epoch [    8/   20] | d_loss: 0.7376 | g_loss: 1.7054
# Epoch [    8/   20] | d_loss: 1.1341 | g_loss: 2.6635
# Epoch [    8/   20] | d_loss: 1.1559 | g_loss: 3.9191
# Epoch [    8/   20] | d_loss: 1.0548 | g_loss: 1.0145
# Epoch [    8/   20] | d_loss: 0.4508 | g_loss: 2.5512
# Epoch [    8/   20] | d_loss: 0.7703 | g_loss: 2.7546
# Epoch [    8/   20] | d_loss: 0.7642 | g_loss: 1.2774
# Epoch [    8/   20] | d_loss: 0.7192 | g_loss: 1.5756
# Epoch [    8/   20] | d_loss: 0.9973 | g_loss: 5.0193
# Epoch [    8/   20] | d_loss: 0.9359 | g_loss: 1.4844
# Epoch [    8/   20] | d_loss: 0.7944 | g_loss: 1.3394
# Epoch [    8/   20] | d_loss: 0.6181 | g_loss: 1.6376
# Epoch [    8/   20] | d_loss: 0.8706 | g_loss: 2.6502
# Epoch [    8/   20] | d_loss: 0.6124 | g_loss: 1.5431
# Epoch [    8/   20] | d_loss: 0.5705 | g_loss: 2.7047
# Epoch [    8/   20] | d_loss: 0.7224 | g_loss: 2.2784
# Epoch [    8/   20] | d_loss: 1.0662 | g_loss: 1.6766
# Epoch [    8/   20] | d_loss: 0.8449 | g_loss: 1.7364
# Epoch [   11/   20] | d_loss: 1.5763 | g_loss: 4.8244
# Epoch [   11/   20] | d_loss: 0.9923 | g_loss: 1.1251
# Epoch [   12/   20] | d_loss: 1.0205 | g_loss: 5.1647
# Epoch [   12/   20] | d_loss: 0.2266 | g_loss: 3.6760
# Epoch [   12/   20] | d_loss: 0.2777 | g_loss: 3.7098
# Epoch [   12/   20] | d_loss: 0.5862 | g_loss: 3.4293
# Epoch [   12/   20] | d_loss: 0.9536 | g_loss: 4.0672
# Epoch [   12/   20] | d_loss: 1.1542 | g_loss: 3.6506
# Epoch [   12/   20] | d_loss: 0.9129 | g_loss: 3.8423
# Epoch [   12/   20] | d_loss: 0.3307 | g_loss: 2.5511
# Epoch [   12/   20] | d_loss: 0.7327 | g_loss: 2.9540
# Epoch [   12/   20] | d_loss: 1.0894 | g_loss: 1.3273
# Epoch [   12/   20] | d_loss: 0.9570 | g_loss: 0.9245
# Epoch [   12/   20] | d_loss: 0.2676 | g_loss: 2.1204
# Epoch [   12/   20] | d_loss: 0.9039 | g_loss: 2.4463
# Epoch [   12/   20] | d_loss: 0.7259 | g_loss: 1.1420
# Epoch [   12/   20] | d_loss: 0.2668 | g_loss: 2.8570
# Epoch [   12/   20] | d_loss: 0.8114 | g_loss: 1.3405
# Epoch [   12/   20] | d_loss: 0.4300 | g_loss: 1.4172
# Epoch [   12/   20] | d_loss: 0.7465 | g_loss: 2.7935
# Epoch [   12/   20] | d_loss: 0.7898 | g_loss: 4.8771
# Epoch [   12/   20] | d_loss: 0.3279 | g_loss: 2.1415
# Epoch [   12/   20] | d_loss: 0.3593 | g_loss: 3.7673
# Epoch [   12/   20] | d_loss: 0.6496 | g_loss: 2.4263
# Epoch [   12/   20] | d_loss: 0.8134 | g_loss: 1.6789
# Epoch [   12/   20] | d_loss: 0.6282 | g_loss: 2.1046
# Epoch [   12/   20] | d_loss: 0.8470 | g_loss: 3.7650
# Epoch [   12/   20] | d_loss: 0.4727 | g_loss: 2.1268
# Epoch [   12/   20] | d_loss: 0.4648 | g_loss: 2.6722
# Epoch [   12/   20] | d_loss: 0.5179 | g_loss: 3.0896
# Epoch [   12/   20] | d_loss: 1.2014 | g_loss: 3.1312
# Epoch [   12/   20] | d_loss: 0.3642 | g_loss: 3.9209
# Epoch [   12/   20] | d_loss: 0.8373 | g_loss: 1.4606
# Epoch [   12/   20] | d_loss: 1.7726 | g_loss: 1.0737
# Epoch [   12/   20] | d_loss: 0.8305 | g_loss: 1.2056

# %% [markdown]
# ## Training loss
#
# Plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# View samples of images from the generator, and answer a question about the strengths and weaknesses of your trained models.

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
_ = view_samples(-1, samples)

# %% [markdown]
# ### Question: What do you notice about your generated samples and how might you improve this model?
# When you answer this question, consider the following factors:
# * The dataset is biased; it is made of "celebrity" faces that are mostly white
# * Model size; larger models have the opportunity to learn more features in a data feature space
# * Optimization strategy; optimizers and number of epochs affect your final result

# %% [markdown]
# **Answer:**
# It is clearly observed that bias in dataset highly affects generated samples. Mostly white faces are generated. When skin color is changed, quality of generated faces are decresing. Also, foreheads and cheeks are not clear in the some training samples, so it is another bias in the dataset. These regions look challenge to generate new faces.
# Generating more realistic faces is possible with larger dataset and model but it is required more computational power and time. Also, adjusting hyperparameters such epochs, batch size and number of hidden units provides smaller loss in generative model. For example, *epochs can be increased, batch size may be doubled as 16, in the first version of the model it is 8, and learning rate may be decreased to get better faces.*
# During my reviews, I add Dropout layers to decrease loss value and studying on effect of leaky relu slope on the predictions.

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "problem_unittests.py" files in your submission.
